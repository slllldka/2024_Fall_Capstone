# %% [markdown]
# # Dataset
# We firstly open the dataset created by us manually and with help of chatGPT to get the foods' description. If we use an AI to generate descriptions of food, then we just need to get new food names and get the descriptions easily. This will make the program scalable.

# %%
import pandas as pd
file_path = 'updated_food_data2-1.xlsx'
updated_food_data_df = pd.read_excel(file_path)
updated_food_data_df
# Out:
#                                  english_name               Characteristic  \
# 0                                   Gamjajeon                 Crispy, mild
# 1   Sundae Gukbap (Korean Blood Sausage Soup)                       earthy
# 2             Suyuk Gukbap (Boiled Pork Soup)                       earthy
# 3                     Pork Bone Hangover Soup                 spicy, nutty
# 4                            Bean Sprout Soup  crunchy, nutty, mild, clean
# ..                                        ...                          ...
# 80                                      Salad  Crunchy, mild, nutty, light
# 81                                   Sandwich                  Mild, nutty
# 82                                  Hamburger         Crispy, nutty, salty
# 83                             Chicken Burger   Crispy, nutty, salty, mild
# 84                              Shrimp Burger   Crispy, nutty, salty, mild
#
#     cuisine                  category  \
# 0    Korean                     fried
# 1    Korean                 rice,soup
# 2    Korean                 rice,soup
# 3    Korean                 rice,soup
# 4    Korean                 rice,soup
# ..      ...                       ...
# 80   Korean                vegetables
# 81  Western                     bread
# 82  Western     bread,meat,vegetables
# 83  Western    bread,fried,vegetables
# 84  Western  bread,seafood,vegetables
#
#                                    English_ingredient  \
# 0                  Potatoes, water, salt, cooking oil
# 1   Commercial, green onion, cheongyang pepper, co...
# 2   Pork belly, radish, bean sprouts, boiled sirae...
# 3                      Pork spine, rugs, leeks, water
# 4   Bean sprouts, leek, cheongyang pepper, shrimp,...
# ..                                                ...
# 80  Plain yogurt, honey, lemon juice, mayonnaise, ...
# 81                      Bread, onion, cabbage, butter
# 82  Pork, beef, onion, pickle, paprika, cheese, ha...
# 83                    Morning bread, cabbage, chicken
# 84  Shrimp meat, onion, bread crumbs, eggs, flour,...
#
#                                           description   vegetarians  \
# 0   Gamjajeon is a type of pancake made primarily ...             1
# 1   Sundae Gukbap is a hearty Korean soup made wit...             1
# 2   Suyuk Gukbap is a comforting Korean soup made ...             0
# 3   Pork Bone Hangover Soup, known as Gamjatang in...             0
# 4   Bean Sprout Soup, known as Kongnamul-guk in Ko...             1
# ..                                                ...           ...
# 80  Salad is a versatile dish made from a mix of f...             1
# 81  A sandwich is a versatile dish consisting of f...             1
# 82  A hamburger is a popular dish consisting of a ...             0
# 83  A chicken burger is a flavorful sandwich made ...             0
# 84  A shrimp burger is a delicious seafood twist o...             0
#
#             allergy
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4    shellfish, soy
# ..              ...
# 80              NaN
# 81              NaN
# 82              NaN
# 83              NaN
# 84  shellfish, eggs
#
# [85 rows x 8 columns]

# %% [markdown]
# # Text Preprocessing, Noun Extraction, and Entity Recognition for Keyword Extraction
#
# 1. **`preprocess_text` Function**:
#    - This function receives a raw text string as input.
#    - It tokenizes the text, removing common stopwords and non-alphabetic tokens to filter out unimportant words.
#    - Each token is then lemmatized (reduced to its base or "dictionary" form) using WordNetLemmatizer from NLTK. Lemmatization is crucial as it standardizes words, making variations of a word like "running" and "runs" equivalent to "run".
#    - The resulting list of cleaned, meaningful words is returned as output.
#
# 2. **`get_nouns` Function**:
#    - This function receives a list of tokens, typically after preprocessing.
#    - It uses part-of-speech (POS) tagging to identify nouns, which are often central to determining the main subjects and concepts in the text.
#    - Only words tagged as nouns (POS tags beginning with "NN") are kept, as they tend to represent entities or topics.
#    - This filtered list of nouns is returned, narrowing down the tokens to those likely relevant for keywords.
#
# 3. **`get_entities` Function**:
#    - This function performs named entity recognition (NER) on the original text using spaCy’s language model.
#    - Named entities are proper nouns, locations, dates, and other significant phrases that provide context and specificity.
#    - The function returns a list of these entities, capturing essential, named information in the text.
#
# 4. **`extract_keywords` Function**:
#    - This function orchestrates the keyword extraction by combining the outputs from `preprocess_text`, `get_nouns`, and `get_entities`.
#    - It first preprocesses the text, then extracts nouns from the processed tokens, and finally recognizes named entities in the original text.
#    - The function merges the lists of nouns and entities, removing duplicates, to produce a final list of keywords that encompass both general topics and specific entities.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import string
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words("english"))
    tokens = nltk.word_tokenize(text)

    lemmas = []
    for token in tokens:
        if token.lower() not in stop_words and token.isalpha():
            lemma = lemmatizer.lemmatize(token.lower())
            lemmas.append(lemma)
    return lemmas

def get_nouns(tokens):
    pos_tags = pos_tag(tokens)
    nouns = []
    for word, pos in pos_tags:[savory, something]
        if pos.startswith('NN'):
            nouns.append(word)
    return nouns


def get_entities(text):
    doc = nlp(text)
    entities = [ent.text for ent in doc.ents]
    return entities


def extract_keywords(text):
    lemmas = preprocess_text(text)
    nouns = get_nouns(lemmas)
    entities = get_entities(text)
    relevant_keywords = list(set(nouns + entities))
    return relevant_keywords

# %%
updated_food_data_df['keywords'] = updated_food_data_df['description'].apply(

    lambda x: extract_keywords(str(x)) if isinstance(x, str) else extract_keywords("")

)
updated_food_data_df
# Out:
# Entities: ['Gamjajeon']
# Entities: ['Sundae Gukbap', 'Korean', 'Korean', 'Sundae Gukbap', 'Korea']
# Entities: ['Suyuk Gukbap', 'Korean', 'meaty', 'Rice', 'Suyuk Gukbap']
# Entities: ['Gamjatang', 'Korean', 'hours', 'gamjatang', 'Gamjatang']
# Entities: ['Bean Sprout Soup', 'Kongnamul', 'Korean', 'Bean Sprout Soup']
# Entities: ['Kimchi Jjigae', 'Kimchi Stew', 'Korean', 'Korean', 'Korean', 'kimchi', 'Kimchi Jjigae', 'days']
# Entities: ['Doenjang Jjigae', 'Korean', 'doenjang', 'Beef Brisket', 'Doenjang Jjigae']
# Entities: ['Jjigae', 'Soft Tofu Stew', 'Korean', 'Korean', 'Korean', 'Jjigae', 'Sundubu Jjigae', 'chilly days']
# Entities: ['Budae Jjigae', 'Army Stew', 'Korean', 'the Korean War', 'Korean', 'American', 'Spam', 'Korean', 'Korean', 'doenjang', 'Budae Jjigae', 'Budae Jjigae', 'days']
# Entities: ['Galbi Jjim', 'Braised Short Ribs', 'Korean', 'first', 'Galbi Jjim']
# Entities: ['Jjimdak', 'Braised Chicken', 'Korean', 'Korean', 'Jjimdak']
# Entities: ['Beef Bowl', 'Japanese', 'shichimi togarashi', 'Japanese', 'Gyudon']
# Entities: ['Chashu Don', 'Pork Bowl', 'Japanese', 'Chashu Don']
# Entities: ['Katsudon', 'Pork Cutlet Bowl', 'Japanese', 'dashi', 'Japanese', 'Katsudon', 'Katsudon', 'Japan']
# Entities: ['Sake Don', 'Salmon Rice Bowl', 'Japanese', 'ikura', 'Sake Don']
# Entities: ['Mayo Rice Bowl', 'Japanese', 'Mayo Rice Bowl']
# Entities: ['Samgyeopsal Rice Bowl', 'Pork Belly Rice Bowl', 'Korean', 'Korean', 'Kimchi', 'Korean']
# Entities: ['Jeyuk Deopbap', 'Spicy Pork Rice Bowl', 'Korean', 'Korean', 'Korean', 'Jeyuk Deopbap', 'Korean']
# Entities: ['Curry Rice', 'Kare Raisu', 'Japanese', 'Japanese', 'Japanese', 'Indian', 'Thai', 'Curry Rice']
# Entities: ['Korean', 'Spam', 'Spam', 'Spam', 'Korean', 'Kimchi Fried Rice']
# Entities: ['Japanese']
# Entities: []
# Entities: ['Gamjatang', 'Pork Bone Soup', 'Korean', 'hours', 'Gamjatang', 'Gamjatang']
# Entities: ['Samgyetang', 'Ginseng Chicken Soup', 'Korean', 'jujubes', 'Korean', 'Samgyetang', 'the hot summer months']
# Entities: ['Sichuan']
# Entities: ['Odeng Tang', 'Cake Soup', 'Korean', 'Odeng Tang']
# Entities: ['Jjajangmyeon', 'Black Bean Noodles', 'Korean-Chinese', 'black bean paste', 'Jjajangmyeon']
# Entities: ['Jjamppong', 'Spicy Seafood Noodles', 'Korean', 'Korean', 'Jjamppong']
# Entities: ['Sweet', 'Sour Pork', 'Korean']
# Entities: ['Rice', 'Black Bean Sauce', 'Korean-Chinese', 'black bean paste']
# Entities: ['Rice', 'Korean']
# Entities: ['Soy Sauce Egg Rice']
# Entities: ['Mapo Tofu', 'Chinese', 'doubanjiang', 'Sichuan', 'Mapo Tofu']
# Entities: ['Mixed Rice', 'Korean', 'Korean']
# Entities: ['Mandu', 'Korean', 'days', 'Korean New Year']
# Entities: ['Rice Cake Soup', 'Tteokguk', 'Korean', 'Tteokguk', 'Korean New Year', 'another year in age', 'Rice Cake Soup', 'Korean']
# Entities: ['Bajirak Kalguksu', 'Korean']
# Entities: ['Japanese', 'kombu']
# Entities: ['Offal Hot Pot', 'Japanese', 'months']
# Entities: ['Mille-feuille Nabe', 'Layered Hot Pot', 'Japanese', 'Mille-feuille Nabe']
# Entities: ['Sukiyaki', 'Japanese', 'shirataki', 'Sukiyaki']
# Entities: []
# Entities: ['Rice Bowl']
# Entities: []
# Entities: ['Tendon', 'Tempura Rice Bowl', 'Japanese', 'dashi', 'Tendon', 'Tendon']
# Entities: ['Rice Rolls', 'Korean', 'Kimbap']
# Entities: ['hours']
# Entities: ['Tteokbokki', 'Spicy Rice Cakes', 'Korean', 'Korean', 'Korean', 'Tteokbokki']
# Entities: ['Bibim Guksu*', 'Korean', 'Korean']
# Entities: ['Janchi Guksu', 'Banquet Noodles', 'Korean', 'Janchi Guksu', 'days']
# Entities: ['Cold Noodles', 'Broth', 'Korean', 'Korean']
# Entities: ['Bibim Naengmyeon', 'Spicy Cold Noodles', 'Korean', 'Korean', 'Korean', 'Bibim Naengmyeon']
# Entities: ['Japanese', 'dashi', 'Japanese', 'bonito', 'any season', 'tempura', 'kamaboko', 'shichimi togarashi', 'Japanese']
# Entities: ['Cream Pasta', 'Italian', 'Parmesan', 'Garlic', 'Parmesan', 'Cream Pasta']
# Entities: ['Oil Pasta', 'Italian', 'Parmesan']
# Entities: ['Tomato Pasta', 'Italian', 'Parmesan', 'Tomato Pasta']
# Entities: ['Dough Soup', 'Korean', 'Sujebi', 'Sujebi', 'cold days']
# Entities: ['Chicken']
# Entities: ['Mozzarella', 'Parmesan', 'Margherita']
# Entities: ['Grilled Duck', 'five']
# Entities: []
# Entities: []
# Entities: ['Beef', 'Maillard']
# Entities: ['Seolleongtang', 'Bone Soup', 'Korean', 'several hours', 'Seolleongtang']
# Entities: []
# Entities: []
# Entities: ['Nakji Bokkeum*', 'Korean', 'Korean', 'Korean']
# Entities: ['Octopus', 'Nakji Bokkeum*', 'Korean', 'Octopus']
# Entities: ['Jeyuk Bokkeum', 'Korean', 'Korean']
# Entities: ['Ojingeo Bokkeum', 'Korean', 'Korean']
# Entities: ['Dakgalbi', 'Spicy Stir-fried Chicken', 'Korean', 'Korean', 'Dakgalbi']
# Entities: ['Japanese', 'Tonkatsu', 'Worcestershire', 'Tonkatsu']
# Entities: ['Cutlet', 'Cutlet', 'Fish Cutlet']
# Entities: ['Rice', 'Roe', 'Ikura Don', 'Japanese', 'Rice', 'Roe']
# Entities: ['Korean', 'Korean', 'the summer months']
# Entities: ['Japanese', 'yellowtail', 'Sashimi']
# Entities: ['Korean', 'Godeungeo Jorim', 'Korean']
# Entities: ['Spicy Chicken Feet', 'Korean', 'Korean', 'Spicy Chicken Feet']
# Entities: ['Vietnamese', 'Vietnamese']
# Entities: ['Suyuk', 'Boiled Pork Slices', 'Korean', 'Korean', 'Suyuk', 'Suyuk']
# Entities: ['Salad', 'Caesar']
# Entities: ['turkey']
# Entities: ['patty', 'patty', 'Classic']
# Entities: ['patty', 'Classic']
# Entities: ['patty', 'patty']
#                                  english_name               Characteristic  \
# 0                                   Gamjajeon                 Crispy, mild
# 1   Sundae Gukbap (Korean Blood Sausage Soup)                       earthy
# 2             Suyuk Gukbap (Boiled Pork Soup)                       earthy
# 3                     Pork Bone Hangover Soup                 spicy, nutty
# 4                            Bean Sprout Soup  crunchy, nutty, mild, clean
# ..                                        ...                          ...
# 80                                      Salad  Crunchy, mild, nutty, light
# 81                                   Sandwich                  Mild, nutty
# 82                                  Hamburger         Crispy, nutty, salty
# 83                             Chicken Burger   Crispy, nutty, salty, mild
# 84                              Shrimp Burger   Crispy, nutty, salty, mild
#
#     cuisine                  category  \
# 0    Korean                     fried
# 1    Korean                 rice,soup
# 2    Korean                 rice,soup
# 3    Korean                 rice,soup
# 4    Korean                 rice,soup
# ..      ...                       ...
# 80   Korean                vegetables
# 81  Western                     bread
# 82  Western     bread,meat,vegetables
# 83  Western    bread,fried,vegetables
# 84  Western  bread,seafood,vegetables
#
#                                    English_ingredient  \
# 0                  Potatoes, water, salt, cooking oil
# 1   Commercial, green onion, cheongyang pepper, co...
# 2   Pork belly, radish, bean sprouts, boiled sirae...
# 3                      Pork spine, rugs, leeks, water
# 4   Bean sprouts, leek, cheongyang pepper, shrimp,...
# ..                                                ...
# 80  Plain yogurt, honey, lemon juice, mayonnaise, ...
# 81                      Bread, onion, cabbage, butter
# 82  Pork, beef, onion, pickle, paprika, cheese, ha...
# 83                    Morning bread, cabbage, chicken
# 84  Shrimp meat, onion, bread crumbs, eggs, flour,...
#
#                                           description   vegetarians  \
# 0   Gamjajeon is a type of pancake made primarily ...             1
# 1   Sundae Gukbap is a hearty Korean soup made wit...             1
# 2   Suyuk Gukbap is a comforting Korean soup made ...             0
# 3   Pork Bone Hangover Soup, known as Gamjatang in...             0
# 4   Bean Sprout Soup, known as Kongnamul-guk in Ko...             1
# ..                                                ...           ...
# 80  Salad is a versatile dish made from a mix of f...             1
# 81  A sandwich is a versatile dish consisting of f...             1
# 82  A hamburger is a popular dish consisting of a ...             0
# 83  A chicken burger is a flavorful sandwich made ...             0
# 84  A shrimp burger is a delicious seafood twist o...             0
#
#             allergy                                           keywords
# 0               NaN  [brown, crunch, help, oil, gamjajeon, flavor, ...
# 1               NaN  [blood, korea, flavor, stock, bone, slice, por...
# 2               NaN  [diner, Rice, flavor, ginger, shrimp, bone, di...
# 3               NaN  [addition, seed, name, flavor, meatiness, pota...
# 4    shellfish, soy  [sprinkle, flavor, Kongnamul, soy, ingredient,...
# ..              ...                                                ...
# 80              NaN  [variety, fruit, crunch, seed, ranch, flavor, ...
# 81              NaN  [variety, flavor, meat, cucumber, club, simple...
# 82              NaN  [avocado, flavor, mushroom, food, dish, meal, ...
# 83              NaN  [freshness, burger, versatility, flavor, meal,...
# 84  shellfish, eggs  [addition, seafood, crunch, avocado, burger, t...
#
# [85 rows x 9 columns]

# %%
def remove_duplicates(keywords):
    if isinstance(keywords, list):
        return list(set(keywords))
    return keywords  
updated_food_data_df['keywords'] = updated_food_data_df['keywords'].apply(remove_duplicates)

updated_food_data_df
# Out:
#                                  english_name               Characteristic  \
# 0                                   Gamjajeon                 Crispy, mild
# 1   Sundae Gukbap (Korean Blood Sausage Soup)                       earthy
# 2             Suyuk Gukbap (Boiled Pork Soup)                       earthy
# 3                     Pork Bone Hangover Soup                 spicy, nutty
# 4                            Bean Sprout Soup  crunchy, nutty, mild, clean
# ..                                        ...                          ...
# 80                                      Salad  Crunchy, mild, nutty, light
# 81                                   Sandwich                  Mild, nutty
# 82                                  Hamburger         Crispy, nutty, salty
# 83                             Chicken Burger   Crispy, nutty, salty, mild
# 84                              Shrimp Burger   Crispy, nutty, salty, mild
#
#     cuisine                  category  \
# 0    Korean                     fried
# 1    Korean                 rice,soup
# 2    Korean                 rice,soup
# 3    Korean                 rice,soup
# 4    Korean                 rice,soup
# ..      ...                       ...
# 80   Korean                vegetables
# 81  Western                     bread
# 82  Western     bread,meat,vegetables
# 83  Western    bread,fried,vegetables
# 84  Western  bread,seafood,vegetables
#
#                                    English_ingredient  \
# 0                  Potatoes, water, salt, cooking oil
# 1   Commercial, green onion, cheongyang pepper, co...
# 2   Pork belly, radish, bean sprouts, boiled sirae...
# 3                      Pork spine, rugs, leeks, water
# 4   Bean sprouts, leek, cheongyang pepper, shrimp,...
# ..                                                ...
# 80  Plain yogurt, honey, lemon juice, mayonnaise, ...
# 81                      Bread, onion, cabbage, butter
# 82  Pork, beef, onion, pickle, paprika, cheese, ha...
# 83                    Morning bread, cabbage, chicken
# 84  Shrimp meat, onion, bread crumbs, eggs, flour,...
#
#                                           description   vegetarians  \
# 0   Gamjajeon is a type of pancake made primarily ...             1
# 1   Sundae Gukbap is a hearty Korean soup made wit...             1
# 2   Suyuk Gukbap is a comforting Korean soup made ...             0
# 3   Pork Bone Hangover Soup, known as Gamjatang in...             0
# 4   Bean Sprout Soup, known as Kongnamul-guk in Ko...             1
# ..                                                ...           ...
# 80  Salad is a versatile dish made from a mix of f...             1
# 81  A sandwich is a versatile dish consisting of f...             1
# 82  A hamburger is a popular dish consisting of a ...             0
# 83  A chicken burger is a flavorful sandwich made ...             0
# 84  A shrimp burger is a delicious seafood twist o...             0
#
#             allergy                                           keywords
# 0               NaN  [brown, crunch, salt, oil, gamjajeon, flavor, ...
# 1               NaN  [blood, korea, flavor, stock, bone, slice, por...
# 2               NaN  [diner, Rice, ginger, flavor, shrimp, bone, di...
# 3               NaN  [addition, seed, name, flavor, meatiness, pota...
# 4    shellfish, soy  [sprinkle, flavor, Kongnamul, soy, ingredient,...
# ..              ...                                                ...
# 80              NaN  [variety, ranch, seed, fruit, crunch, flavor, ...
# 81              NaN  [variety, flavor, meat, cucumber, club, simple...
# 82              NaN  [avocado, flavor, mushroom, food, dish, meal, ...
# 83              NaN  [freshness, burger, versatility, flavor, meal,...
# 84  shellfish, eggs  [addition, seafood, crunch, avocado, burger, t...
#
# [85 rows x 9 columns]

# %%
updated_food_data_df['keywords'] = updated_food_data_df['keywords'].apply(
    lambda keywords: [keyword for keyword in keywords if len(keyword) > 2]
)

updated_food_data_df
# Out:
#                                  english_name               Characteristic  \
# 0                                   Gamjajeon                 Crispy, mild
# 1   Sundae Gukbap (Korean Blood Sausage Soup)                       earthy
# 2             Suyuk Gukbap (Boiled Pork Soup)                       earthy
# 3                     Pork Bone Hangover Soup                 spicy, nutty
# 4                            Bean Sprout Soup  crunchy, nutty, mild, clean
# ..                                        ...                          ...
# 80                                      Salad  Crunchy, mild, nutty, light
# 81                                   Sandwich                  Mild, nutty
# 82                                  Hamburger         Crispy, nutty, salty
# 83                             Chicken Burger   Crispy, nutty, salty, mild
# 84                              Shrimp Burger   Crispy, nutty, salty, mild
#
#     cuisine                  category  \
# 0    Korean                     fried
# 1    Korean                 rice,soup
# 2    Korean                 rice,soup
# 3    Korean                 rice,soup
# 4    Korean                 rice,soup
# ..      ...                       ...
# 80   Korean                vegetables
# 81  Western                     bread
# 82  Western     bread,meat,vegetables
# 83  Western    bread,fried,vegetables
# 84  Western  bread,seafood,vegetables
#
#                                    English_ingredient  \
# 0                  Potatoes, water, salt, cooking oil
# 1   Commercial, green onion, cheongyang pepper, co...
# 2   Pork belly, radish, bean sprouts, boiled sirae...
# 3                      Pork spine, rugs, leeks, water
# 4   Bean sprouts, leek, cheongyang pepper, shrimp,...
# ..                                                ...
# 80  Plain yogurt, honey, lemon juice, mayonnaise, ...
# 81                      Bread, onion, cabbage, butter
# 82  Pork, beef, onion, pickle, paprika, cheese, ha...
# 83                    Morning bread, cabbage, chicken
# 84  Shrimp meat, onion, bread crumbs, eggs, flour,...
#
#                                           description   vegetarians  \
# 0   Gamjajeon is a type of pancake made primarily ...             1
# 1   Sundae Gukbap is a hearty Korean soup made wit...             1
# 2   Suyuk Gukbap is a comforting Korean soup made ...             0
# 3   Pork Bone Hangover Soup, known as Gamjatang in...             0
# 4   Bean Sprout Soup, known as Kongnamul-guk in Ko...             1
# ..                                                ...           ...
# 80  Salad is a versatile dish made from a mix of f...             1
# 81  A sandwich is a versatile dish consisting of f...             1
# 82  A hamburger is a popular dish consisting of a ...             0
# 83  A chicken burger is a flavorful sandwich made ...             0
# 84  A shrimp burger is a delicious seafood twist o...             0
#
#             allergy                                           keywords
# 0               NaN  [brown, crunch, salt, oil, gamjajeon, flavor, ...
# 1               NaN  [blood, korea, flavor, stock, bone, slice, por...
# 2               NaN  [diner, Rice, ginger, flavor, shrimp, bone, di...
# 3               NaN  [addition, seed, name, flavor, meatiness, pota...
# 4    shellfish, soy  [sprinkle, flavor, Kongnamul, soy, ingredient,...
# ..              ...                                                ...
# 80              NaN  [variety, ranch, seed, fruit, crunch, flavor, ...
# 81              NaN  [variety, flavor, meat, cucumber, club, simple...
# 82              NaN  [avocado, flavor, mushroom, food, dish, meal, ...
# 83              NaN  [freshness, burger, versatility, flavor, meal,...
# 84  shellfish, eggs  [addition, seafood, crunch, avocado, burger, t...
#
# [85 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
from collections import Counter

keywords_list = updated_food_data_df['keywords'].dropna().sum()
keywords_counts = Counter(keywords_list)

top_keywords_df = pd.DataFrame(keywords_counts.items(), columns=['Keyword', 'Count'])
top_keywords_df = top_keywords_df.sort_values(by='Count', ascending=False).head(30)

plt.figure(figsize=(10, 6))
plt.bar(top_keywords_df['Keyword'], top_keywords_df['Count'])
plt.xlabel('Keywords')
plt.ylabel('Frequency')
plt.title('Top 30 Keywords by Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
keywords_list = updated_food_data_df['keywords'].dropna().sum()
keywords_counts = Counter(keywords_list)
least_keywords_df = pd.DataFrame(keywords_counts.items(), columns=['Keyword', 'Count'])
least_keywords_df = least_keywords_df.sort_values(by='Count', ascending=True).head(20)

plt.figure(figsize=(10, 6))
plt.bar(least_keywords_df['Keyword'], least_keywords_df['Count'])
plt.xlabel('Keywords')
plt.ylabel('Frequency')
plt.title('20 Least Frequent Keywords')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Analyzing Chat GPT's text
# We asked chat GPT to write some messages the user's could tell us on the app and also to tell us the positive and negative keywords of the message. Using that we can measure how well our application is working on finding keywords and also analyzing the sentiment of them.

# %%
messages = []
positive_keywords = []
negative_keywords = []
mapping_file_path_extended = 'food_message_keywords_mapping_extended.txt'

with open(mapping_file_path_extended, 'r') as file:
    for line in file:
        if line.startswith("Message:"):
            messages.append(line[len("Message: "):].strip())
        elif line.startswith("Positive Keywords:"):
            positive_keywords.append(line[len("Positive Keywords: "):].strip().split(", "))
        elif line.startswith("Negative Keywords:"):
            negative_keywords.append(line[len("Negative Keywords: "):].strip().split(", "))

df_trial = pd.DataFrame({
    "message": messages,
    "positive_keywords": positive_keywords,
    "negative_keywords": negative_keywords
})

# %%
df_trial
# Out:
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...               [None]
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.               [None]
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.               [None]
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.               [None]
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.               [None]
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.               [None]
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...               [None]
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.               [None]
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.               [None]
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords
# 0             [None]
# 1             [None]
# 2             [None]
# 3             [None]
# 4             [None]
# 5            [fried]
# 6            [dairy]
# 7             [None]
# 8             [None]
# 9             [None]
# 10            [None]
# 11            [None]
# 12            [None]
# 13          [greasy]
# 14            [None]
# 15            [None]
# 16          [sugary]
# 17            [meat]
# 18           [spicy]
# 19            [None]
# 20            [None]
# 21          [garlic]
# 22         [filling]
# 23            [None]
# 24    [sour, bitter]
# 25            [None]
# 26            [None]
# 27       [shellfish]
# 28            [None]
# 29            [None]
# 30        [red meat]
# 31           [dairy]
# 32            [None]
# 33            [rice]
# 34            [None]
# 35  [beans, legumes]
# 36            [None]
# 37          [sweets]
# 38         [intense]
# 39           [heavy]
# 40            [None]
# 41            [None]
# 42          [onions]
# 43            [None]
# 44            [None]

# %%
df_trial['keywords'] = df_trial['message'].apply(

    lambda x: extract_keywords(str(x)) if isinstance(x, str) else extract_keywords("")

)
df_trial['keywords'] = df_trial['keywords'].apply(remove_duplicates)
df_trial
# Out:
# Entities: ['tonight']
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: ['today']
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: ['today']
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: ['today']
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: ['today']
# Entities: []
# Entities: []
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...               [None]
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.               [None]
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.               [None]
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.               [None]
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.               [None]
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.               [None]
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...               [None]
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.               [None]
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.               [None]
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords                                 keywords
# 0             [None]        [feel, something, tonight, spicy]
# 1             [None]                              [something]
# 2             [None]                      [meal, lot, veggie]
# 3             [None]                         [eat, something]
# 4             [None]                      [savory, something]
# 5            [fried]              [want, anything, something]
# 6            [dairy]  [dairy, stomach, right, handle, please]
# 7             [None]                          [mood, seafood]
# 8             [None]                                   [soup]
# 9             [None]                      [prefer, something]
# 10            [None]                      [feel, bowl, pasta]
# 11            [None]                          [chicken, dish]
# 12            [None]                       [light, something]
# 13          [greasy]                        [avoid, anything]
# 14            [None]                       [spice, something]
# 15            [None]                     [workout, something]
# 16          [sugary]                                       []
# 17            [meat]                 [today, something, meat]
# 18           [spicy]                      [food, mood, spicy]
# 19            [None]                                   [dish]
# 20            [None]                              [something]
# 21          [garlic]                  [garlic, anything, lot]
# 22         [filling]                         [snack, filling]
# 23            [None]                    [feel, food, comfort]
# 24    [sour, bitter]                [avoid, anything, bitter]
# 25            [None]                      [savory, something]
# 26            [None]                         [option, prefer]
# 27       [shellfish]                       [please, allergic]
# 28            [None]                       [something, spicy]
# 29            [None]               [something, suggest, pair]
# 30        [red meat]                   [chicken, today, meat]
# 31           [dairy]               [dairy, creamy, something]
# 32            [None]                            [hint, lemon]
# 33            [rice]             [feel, anything, work, rice]
# 34            [None]                              [something]
# 35  [beans, legumes]                           [bean, legume]
# 36            [None]                               [mushroom]
# 37          [sweets]                    [snack, salty, today]
# 38         [intense]            [something, nothing, intense]
# 39           [heavy]                      [cheesy, something]
# 40            [None]                                   [dish]
# 41            [None]                        [herb, meal, lot]
# 42          [onions]                  [onion, today, nothing]
# 43            [None]                           [meal, prefer]
# 44            [None]                                   [dish]

# %%
df_trial['positive_keywords'] = df_trial['positive_keywords'].apply(lambda x: [kw for kw in x if kw != "None"])
df_trial['negative_keywords'] = df_trial['negative_keywords'].apply(lambda x: [kw for kw in x if kw != "None"])

df_trial
# Out:
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...                   []
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.                   []
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.                   []
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.                   []
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.                   []
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.                   []
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...                   []
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.                   []
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.                   []
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords                                 keywords
# 0                 []        [feel, something, tonight, spicy]
# 1                 []                              [something]
# 2                 []                      [meal, lot, veggie]
# 3                 []                         [eat, something]
# 4                 []                      [savory, something]
# 5            [fried]              [want, anything, something]
# 6            [dairy]  [dairy, stomach, right, handle, please]
# 7                 []                          [mood, seafood]
# 8                 []                                   [soup]
# 9                 []                      [prefer, something]
# 10                []                      [feel, bowl, pasta]
# 11                []                          [chicken, dish]
# 12                []                       [light, something]
# 13          [greasy]                        [avoid, anything]
# 14                []                       [spice, something]
# 15                []                     [workout, something]
# 16          [sugary]                                       []
# 17            [meat]                 [today, something, meat]
# 18           [spicy]                      [food, mood, spicy]
# 19                []                                   [dish]
# 20                []                              [something]
# 21          [garlic]                  [garlic, anything, lot]
# 22         [filling]                         [snack, filling]
# 23                []                    [feel, food, comfort]
# 24    [sour, bitter]                [avoid, anything, bitter]
# 25                []                      [savory, something]
# 26                []                         [option, prefer]
# 27       [shellfish]                       [please, allergic]
# 28                []                       [something, spicy]
# 29                []               [something, suggest, pair]
# 30        [red meat]                   [chicken, today, meat]
# 31           [dairy]               [dairy, creamy, something]
# 32                []                            [hint, lemon]
# 33            [rice]             [feel, anything, work, rice]
# 34                []                              [something]
# 35  [beans, legumes]                           [bean, legume]
# 36                []                               [mushroom]
# 37          [sweets]                    [snack, salty, today]
# 38         [intense]            [something, nothing, intense]
# 39           [heavy]                      [cheesy, something]
# 40                []                                   [dish]
# 41                []                        [herb, meal, lot]
# 42          [onions]                  [onion, today, nothing]
# 43                []                           [meal, prefer]
# 44                []                                   [dish]

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Cargar el modelo preentrenado para generación de embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')

def calculate_match_percentage(row, columnName, threshold=0.7):
    positive_embeddings = model.encode(row['positive_keywords'], convert_to_tensor=True) if row['positive_keywords'] else None
    negative_embeddings = model.encode(row['negative_keywords'], convert_to_tensor=True) if row['negative_keywords'] else None
    keywords_embeddings = model.encode(row[columnName], convert_to_tensor=True) if row[columnName] else None

    positive_matches = 0
    negative_matches = 0
    
    if positive_embeddings is not None and keywords_embeddings is not None:
        for positive in positive_embeddings:
            for keyword_embedding in keywords_embeddings:
                similarity = cosine_similarity(positive.unsqueeze(0), keyword_embedding.unsqueeze(0))
                if similarity >= threshold:
                    positive_matches += 1  

    if negative_embeddings is not None and keywords_embeddings is not None:
        for negative in negative_embeddings:
            for keyword_embedding in keywords_embeddings:
                similarity = cosine_similarity(negative.unsqueeze(0), keyword_embedding.unsqueeze(0))
                if similarity >= threshold:
                    negative_matches += 1  

    total_keywords = len(row['positive_keywords']) + len(row['negative_keywords'])
    matched_keywords = positive_matches + negative_matches
    
    return (matched_keywords / total_keywords) * 100 if total_keywords > 0 else 0

df_trial['match_percentage'] = df_trial.apply(calculate_match_percentage, axis=1, columnName='keywords')
df_trial
# Out:
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...                   []
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.                   []
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.                   []
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.                   []
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.                   []
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.                   []
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...                   []
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.                   []
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.                   []
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords                                 keywords  \
# 0                 []        [feel, something, tonight, spicy]
# 1                 []                              [something]
# 2                 []                      [meal, lot, veggie]
# 3                 []                         [eat, something]
# 4                 []                      [savory, something]
# 5            [fried]              [want, anything, something]
# 6            [dairy]  [dairy, stomach, right, handle, please]
# 7                 []                          [mood, seafood]
# 8                 []                                   [soup]
# 9                 []                      [prefer, something]
# 10                []                      [feel, bowl, pasta]
# 11                []                          [chicken, dish]
# 12                []                       [light, something]
# 13          [greasy]                        [avoid, anything]
# 14                []                       [spice, something]
# 15                []                     [workout, something]
# 16          [sugary]                                       []
# 17            [meat]                 [today, something, meat]
# 18           [spicy]                      [food, mood, spicy]
# 19                []                                   [dish]
# 20                []                              [something]
# 21          [garlic]                  [garlic, anything, lot]
# 22         [filling]                         [snack, filling]
# 23                []                    [feel, food, comfort]
# 24    [sour, bitter]                [avoid, anything, bitter]
# 25                []                      [savory, something]
# 26                []                         [option, prefer]
# 27       [shellfish]                       [please, allergic]
# 28                []                       [something, spicy]
# 29                []               [something, suggest, pair]
# 30        [red meat]                   [chicken, today, meat]
# 31           [dairy]               [dairy, creamy, something]
# 32                []                            [hint, lemon]
# 33            [rice]             [feel, anything, work, rice]
# 34                []                              [something]
# 35  [beans, legumes]                           [bean, legume]
# 36                []                               [mushroom]
# 37          [sweets]                    [snack, salty, today]
# 38         [intense]            [something, nothing, intense]
# 39           [heavy]                      [cheesy, something]
# 40                []                                   [dish]
# 41                []                        [herb, meal, lot]
# 42          [onions]                  [onion, today, nothing]
# 43                []                           [meal, prefer]
# 44                []                                   [dish]
#
#     match_percentage
# 0         100.000000
# 1           0.000000
# 2         100.000000
# 3           0.000000
# 4         100.000000
# 5           0.000000
# 6         100.000000
# 7         100.000000
# 8         100.000000
# 9           0.000000
# 10        100.000000
# 11        100.000000
# 12         50.000000
# 13          0.000000
# 14        100.000000
# 15          0.000000
# 16          0.000000
# 17         50.000000
# 18        100.000000
# 19          0.000000
# 20          0.000000
# 21        100.000000
# 22        100.000000
# 23          0.000000
# 24         50.000000
# 25         50.000000
# 26          0.000000
# 27          0.000000
# 28         50.000000
# 29          0.000000
# 30         66.666667
# 31        100.000000
# 32        100.000000
# 33        100.000000
# 34          0.000000
# 35        100.000000
# 36        100.000000
# 37         66.666667
# 38         50.000000
# 39         50.000000
# 40          0.000000
# 41        100.000000
# 42        100.000000
# 43          0.000000
# 44          0.000000

# %%
total_match_percentage = df_trial['match_percentage'].mean()
total_match_percentage
# Out:
# 52.962962962962955

# %%
keywords_set = {keyword for sublist in updated_food_data_df['keywords'] for keyword in sublist}

df_trial['new_keywords'] = df_trial['message'].apply(

    lambda message: [keyword for keyword in keywords_set if keyword in message]

)

# %%
df_trial['match_percentage2'] = df_trial.apply(calculate_match_percentage, axis=1, columnName='new_keywords')

# %%
total_match_percentage = df_trial['match_percentage2'].mean()
total_match_percentage
# Out:
# 61.111111111111114

# %%
df_trial['combined_keywords'] = df_trial.apply(
    lambda row: list(set(row['keywords'] + row['new_keywords'])), axis=1
)

# %%
df_trial['match_percentage3'] = df_trial.apply(calculate_match_percentage, axis=1, columnName='combined_keywords')

# %%
total_match_percentage = df_trial['match_percentage3'].mean()
total_match_percentage
# Out:
# 71.11111111111111

# %% [markdown]
# # Aspect-Based Sentiment Analysis (ABSA) Using DeBERTa Model
#
# We use the `transformers` library to load and apply the model `yangheng/deberta-v3-large-absa-v1.1` for ABSA. The steps are as follows:
#
# 1. **Loading the Model**:
#    - We start by loading the DeBERTa model and tokenizer from Hugging Face's Transformers library.
#
# 2. **Aspect-Based Sentiment Analysis Function**:
#    - The main function, `aspect_based_sentiment_analysis`, takes a text input and a list of aspects to evaluate.
#    - For each aspect, the function:
#      - Concatenates the aspect with the text using a separator (`[SEP]`), following the format needed for ABSA.
#      - Tokenizes this combined input and passes it through the model.
#      - Obtains the model's output, interprets the logits, and maps the predicted class ID to a sentiment label (negative, neutral, or positive).
#    - It returns a dictionary where each aspect is mapped to its predicted sentiment.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

model_name = 'yangheng/deberta-v3-large-absa-v1.1'

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

def aspect_based_sentiment_analysis(text, aspects):
    sentiment_results = {}

    for aspect in aspects:
        aspect_text = f"{text} [SEP] {aspect}"
        inputs = tokenizer(aspect_text, return_tensors='pt', truncation=True)
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_id = logits.argmax().item()
        if predicted_class_id == 0:
            sentiment = "negative"
        elif predicted_class_id == 1:
            sentiment = "neutral"
        elif predicted_class_id == 2:
            sentiment = "positive"

        sentiment_results[aspect] = sentiment

    return sentiment_results
# Out:
# /home/gogenola/anaconda3/lib/python3.12/site-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
df_trial['sentiment_analysis'] = df_trial.apply(lambda row: aspect_based_sentiment_analysis(row['message'], row['combined_keywords']), axis=1)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...                   []
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.                   []
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.                   []
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.                   []
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.                   []
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.                   []
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...                   []
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.                   []
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.                   []
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords                                 keywords  \
# 0                 []        [feel, something, tonight, spicy]
# 1                 []                              [something]
# 2                 []                      [meal, lot, veggie]
# 3                 []                         [eat, something]
# 4                 []                      [savory, something]
# 5            [fried]              [want, anything, something]
# 6            [dairy]  [dairy, stomach, right, handle, please]
# 7                 []                          [mood, seafood]
# 8                 []                                   [soup]
# 9                 []                      [prefer, something]
# 10                []                      [feel, bowl, pasta]
# 11                []                          [chicken, dish]
# 12                []                       [light, something]
# 13          [greasy]                        [avoid, anything]
# 14                []                       [spice, something]
# 15                []                     [workout, something]
# 16          [sugary]                                       []
# 17            [meat]                 [today, something, meat]
# 18           [spicy]                      [food, mood, spicy]
# 19                []                                   [dish]
# 20                []                              [something]
# 21          [garlic]                  [garlic, anything, lot]
# 22         [filling]                         [snack, filling]
# 23                []                    [feel, food, comfort]
# 24    [sour, bitter]                [avoid, anything, bitter]
# 25                []                      [savory, something]
# 26                []                         [option, prefer]
# 27       [shellfish]                       [please, allergic]
# 28                []                       [something, spicy]
# 29                []               [something, suggest, pair]
# 30        [red meat]                   [chicken, today, meat]
# 31           [dairy]               [dairy, creamy, something]
# 32                []                            [hint, lemon]
# 33            [rice]             [feel, anything, work, rice]
# 34                []                              [something]
# 35  [beans, legumes]                           [bean, legume]
# 36                []                               [mushroom]
# 37          [sweets]                    [snack, salty, today]
# 38         [intense]            [something, nothing, intense]
# 39           [heavy]                      [cheesy, something]
# 40                []                                   [dish]
# 41                []                        [herb, meal, lot]
# 42          [onions]                  [onion, today, nothing]
# 43                []                           [meal, prefer]
# 44                []                                   [dish]
#
#     match_percentage                      new_keywords  match_percentage2  \
# 0         100.000000         [eat, icy, spicy, eating]              100.0
# 1           0.000000                           [sweet]              100.0
# 2         100.000000                       [meal, egg]                0.0
# 3           0.000000                             [eat]                0.0
# 4         100.000000                          [savory]              100.0
# 5           0.000000                           [grill]               50.0
# 6         100.000000                   [stomach, ease]                0.0
# 7         100.000000              [food, seafood, sea]              100.0
# 8         100.000000       [comforting, comfort, soup]              100.0
# 9           0.000000                                []                0.0
# 10        100.000000                     [bowl, pasta]              100.0
# 11        100.000000                   [dish, chicken]              100.0
# 12         50.000000               [refreshing, light]              100.0
# 13          0.000000                                []                0.0
# 14        100.000000                      [spice, ice]              100.0
# 15          0.000000                         [protein]              100.0
# 16          0.000000                      [sugar, end]               50.0
# 17         50.000000                  [eat, day, meat]               50.0
# 18        100.000000                [icy, spicy, food]              100.0
# 19          0.000000                            [dish]                0.0
# 20          0.000000                          [noodle]              100.0
# 21        100.000000                          [garlic]              100.0
# 22        100.000000                  [filling, snack]              100.0
# 23          0.000000                   [comfort, food]                0.0
# 24         50.000000                             [bit]                0.0
# 25         50.000000         [crunch, savory, crunchy]              150.0
# 26          0.000000                          [option]                0.0
# 27          0.000000               [fish, shell, ease]                0.0
# 28         50.000000               [icy, spicy, sweet]              100.0
# 29          0.000000                            [pair]                0.0
# 30         66.666667   [fish, eat, day, chicken, meat]              100.0
# 31        100.000000                   [cream, creamy]               50.0
# 32        100.000000               [meal, hint, lemon]              100.0
# 33        100.000000                       [rice, ice]              100.0
# 34          0.000000                           [light]               50.0
# 35        100.000000                      [bean, ease]               50.0
# 36        100.000000                  [dish, mushroom]              100.0
# 37         66.666667  [day, salt, sweet, salty, snack]              100.0
# 38         50.000000                [mild, spice, ice]                0.0
# 39         50.000000                                []                0.0
# 40          0.000000                     [dish, bread]              100.0
# 41        100.000000                      [meal, herb]              100.0
# 42        100.000000                [onion, day, ease]              100.0
# 43          0.000000                      [meal, base]                0.0
# 44          0.000000          [dish, sea, end, season]                0.0
#
#                                     combined_keywords  match_percentage3  \
# 0   [feel, icy, spicy, tonight, eating, eat, somet...              100.0
# 1                                  [sweet, something]              100.0
# 2                            [egg, meal, lot, veggie]              100.0
# 3                                    [eat, something]                0.0
# 4                                 [savory, something]              100.0
# 5                  [want, anything, grill, something]               50.0
# 6       [dairy, stomach, right, handle, ease, please]              100.0
# 7                          [food, mood, sea, seafood]              100.0
# 8                         [comfort, soup, comforting]              100.0
# 9                                 [prefer, something]                0.0
# 10                                [feel, bowl, pasta]              100.0
# 11                                    [chicken, dish]              100.0
# 12                     [refreshing, light, something]              100.0
# 13                                  [anything, avoid]                0.0
# 14                            [spice, ice, something]              100.0
# 15                      [workout, protein, something]              100.0
# 16                                       [end, sugar]               50.0
# 17                 [today, meat, something, eat, day]               50.0
# 18                           [food, mood, icy, spicy]              100.0
# 19                                             [dish]                0.0
# 20                                [noodle, something]              100.0
# 21                            [garlic, anything, lot]              100.0
# 22                                   [snack, filling]              100.0
# 23                              [feel, food, comfort]                0.0
# 24                     [anything, avoid, bitter, bit]               50.0
# 25               [crunchy, savory, crunch, something]              150.0
# 26                                   [option, prefer]                0.0
# 27              [allergic, shell, ease, please, fish]                0.0
# 28                     [sweet, icy, something, spicy]              100.0
# 29                         [suggest, pair, something]                0.0
# 30             [today, meat, fish, chicken, eat, day]              100.0
# 31                  [cream, dairy, creamy, something]              100.0
# 32                                [hint, lemon, meal]              100.0
# 33                  [feel, rice, anything, ice, work]              100.0
# 34                                 [light, something]               50.0
# 35                               [bean, ease, legume]              100.0
# 36                                   [mushroom, dish]              100.0
# 37            [today, sweet, snack, salty, salt, day]              100.0
# 38    [spice, intense, something, mild, ice, nothing]               50.0
# 39                                [cheesy, something]               50.0
# 40                                      [bread, dish]              100.0
# 41                                  [herb, meal, lot]              100.0
# 42                 [today, ease, onion, nothing, day]              100.0
# 43                               [base, meal, prefer]                0.0
# 44                           [season, sea, end, dish]                0.0
#
#                                    sentiment_analysis
# 0   {'feel': 'neutral', 'icy': 'neutral', 'spicy':...
# 1        {'sweet': 'neutral', 'something': 'neutral'}
# 2   {'egg': 'neutral', 'meal': 'neutral', 'lot': '...
# 3         {'eat': 'positive', 'something': 'neutral'}
# 4       {'savory': 'neutral', 'something': 'neutral'}
# 5   {'want': 'neutral', 'anything': 'neutral', 'gr...
# 6   {'dairy': 'negative', 'stomach': 'negative', '...
# 7   {'food': 'neutral', 'mood': 'neutral', 'sea': ...
# 8   {'comfort': 'neutral', 'soup': 'positive', 'co...
# 9       {'prefer': 'neutral', 'something': 'neutral'}
# 10  {'feel': 'positive', 'bowl': 'positive', 'past...
# 11          {'chicken': 'neutral', 'dish': 'neutral'}
# 12  {'refreshing': 'neutral', 'light': 'neutral', ...
# 13       {'anything': 'negative', 'avoid': 'neutral'}
# 14  {'spice': 'positive', 'ice': 'neutral', 'somet...
# 15  {'workout': 'neutral', 'protein': 'positive', ...
# 16            {'end': 'neutral', 'sugar': 'negative'}
# 17  {'today': 'neutral', 'meat': 'negative', 'some...
# 18  {'food': 'negative', 'mood': 'neutral', 'icy':...
# 19                                {'dish': 'neutral'}
# 20     {'noodle': 'neutral', 'something': 'positive'}
# 21  {'garlic': 'negative', 'anything': 'neutral', ...
# 22        {'snack': 'neutral', 'filling': 'negative'}
# 23  {'feel': 'neutral', 'food': 'positive', 'comfo...
# 24  {'anything': 'negative', 'avoid': 'neutral', '...
# 25  {'crunchy': 'neutral', 'savory': 'neutral', 'c...
# 26         {'option': 'neutral', 'prefer': 'neutral'}
# 27  {'allergic': 'neutral', 'shell': 'negative', '...
# 28  {'sweet': 'neutral', 'icy': 'neutral', 'someth...
# 29  {'suggest': 'positive', 'pair': 'positive', 's...
# 30  {'today': 'neutral', 'meat': 'negative', 'fish...
# 31  {'cream': 'positive', 'dairy': 'neutral', 'cre...
# 32  {'hint': 'neutral', 'lemon': 'neutral', 'meal'...
# 33  {'feel': 'positive', 'rice': 'negative', 'anyt...
# 34       {'light': 'neutral', 'something': 'neutral'}
# 35  {'bean': 'negative', 'ease': 'positive', 'legu...
# 36         {'mushroom': 'neutral', 'dish': 'neutral'}
# 37  {'today': 'neutral', 'sweet': 'negative', 'sna...
# 38  {'spice': 'negative', 'intense': 'negative', '...
# 39      {'cheesy': 'neutral', 'something': 'neutral'}
# 40           {'bread': 'neutral', 'dish': 'positive'}
# 41  {'herb': 'positive', 'meal': 'neutral', 'lot':...
# 42  {'today': 'neutral', 'ease': 'negative', 'onio...
# 43  {'base': 'neutral', 'meal': 'neutral', 'prefer...
# 44  {'season': 'neutral', 'sea': 'neutral', 'end':...

# %%
df_trial.iloc[6]['sentiment_analysis']
# Out:
# {'dairy': 'negative',
#  'stomach': 'negative',
#  'right': 'neutral',
#  'handle': 'negative',
#  'ease': 'neutral',
#  'please': 'neutral'}

# %%
from sklearn.metrics.pairwise import cosine_similarity

model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)

def calculate_accuracy_with_similarity(row, threshold=0.7):
    sentiment_results = row['sentiment_analysis']
    positive_keywords = row['positive_keywords']
    negative_keywords = row['negative_keywords']
    positive_embeddings = model.encode(positive_keywords, convert_to_tensor=True) if positive_keywords else []
    negative_embeddings = model.encode(negative_keywords, convert_to_tensor=True) if negative_keywords else []
    
    correct_predictions = 0
    total_counted = 0

    for keyword, predicted_sentiment in sentiment_results.items():
        keyword_embedding = model.encode([keyword], convert_to_tensor=True)
        max_positive_similarity = max([cosine_similarity(keyword_embedding, pos_emb.unsqueeze(0)).item() for pos_emb in positive_embeddings], default=0)
        max_negative_similarity = max([cosine_similarity(keyword_embedding, neg_emb.unsqueeze(0)).item() for neg_emb in negative_embeddings], default=0)

        if max_positive_similarity >= threshold:
            true_sentiment = "positive"
        elif max_negative_similarity >= threshold:
            true_sentiment = "negative"
        else:
            continue  

        if predicted_sentiment == true_sentiment:
            correct_predictions += 1
        total_counted += 1
    return (correct_predictions / total_counted) * 100 if total_counted > 0 else None

df_trial['accuracy_percentage'] = df_trial.apply(calculate_accuracy_with_similarity, axis=1)

df_trial[['message', 'positive_keywords', 'negative_keywords', 'sentiment_analysis', 'accuracy_percentage']]
# Out:
#                                               message    positive_keywords  \
# 0         I feel like eating something spicy tonight.              [spicy]
# 1      I’m craving something sweet but not too heavy.              [sweet]
# 2        Can you suggest a meal with lots of veggies?            [veggies]
# 3   I’d love to have something quick and easy to eat.              [quick]
# 4                   I want something rich and savory.             [savory]
# 5   I don’t want anything fried, maybe something g...            [grilled]
# 6   No dairy, please; my stomach can’t handle it r...                   []
# 7                        I’m in the mood for seafood.            [seafood]
# 8                        How about a comforting soup?               [soup]
# 9                   I’d prefer something gluten-free.        [gluten-free]
# 10            I feel like having a big bowl of pasta.              [pasta]
# 11               Can you suggest a dish with chicken?            [chicken]
# 12    I’m looking for something refreshing and light.  [refreshing, light]
# 13                         Avoid anything too greasy.                   []
# 14  I’m open to trying something new, maybe with e...      [exotic spices]
# 15  I’d like something protein-packed for after my...     [protein-packed]
# 16  Could you recommend a dessert that’s not too s...            [dessert]
# 17        No meat today, I want something vegetarian.         [vegetarian]
# 18            I’m not in the mood for any spicy food.                   []
# 19              Could you suggest a traditional dish?        [traditional]
# 20                   I’d like something with noodles.            [noodles]
# 21        I don’t want anything with a lot of garlic.                   []
# 22    Can you suggest a snack that’s not too filling?              [snack]
# 23              I feel like having some comfort food.       [comfort food]
# 24                 Avoid anything too sour or bitter.                   []
# 25      I’m looking for something crunchy and savory.    [crunchy, savory]
# 26                      I’d prefer a low-carb option.           [low-carb]
# 27                No shellfish, please, I’m allergic.                   []
# 28      I want something that’s both sweet and spicy.       [sweet, spicy]
# 29  Can you suggest something that pairs well with...        [tea pairing]
# 30  No red meat today, I’d rather have fish or chi...      [fish, chicken]
# 31         I want something creamy but without dairy.             [creamy]
# 32     Could you suggest a meal with a hint of lemon?       [lemon flavor]
# 33  I don’t feel like having rice; anything else w...                   []
# 34                I’d like something light and fresh.       [light, fresh]
# 35                    Please avoid beans and legumes.                   []
# 36           Could you suggest a dish with mushrooms?          [mushrooms]
# 37             No sweets today; I want a salty snack.       [salty, snack]
# 38  I’m looking for something mildly spiced, nothi...      [mildly spiced]
# 39    I’m craving something cheesy but not too heavy.             [cheesy]
# 40  Can you suggest a dish that goes well with bread?      [bread pairing]
# 41           I want a meal with a lot of fresh herbs.        [fresh herbs]
# 42                 Nothing with onions today, please.                   []
# 43                     I’d prefer a plant-based meal.        [plant-based]
# 44               Could you recommend a seasonal dish?           [seasonal]
#
#    negative_keywords                                 sentiment_analysis  \
# 0                 []  {'feel': 'neutral', 'icy': 'neutral', 'spicy':...
# 1                 []       {'sweet': 'neutral', 'something': 'neutral'}
# 2                 []  {'egg': 'neutral', 'meal': 'neutral', 'lot': '...
# 3                 []        {'eat': 'positive', 'something': 'neutral'}
# 4                 []      {'savory': 'neutral', 'something': 'neutral'}
# 5            [fried]  {'want': 'neutral', 'anything': 'neutral', 'gr...
# 6            [dairy]  {'dairy': 'negative', 'stomach': 'negative', '...
# 7                 []  {'food': 'neutral', 'mood': 'neutral', 'sea': ...
# 8                 []  {'comfort': 'neutral', 'soup': 'positive', 'co...
# 9                 []      {'prefer': 'neutral', 'something': 'neutral'}
# 10                []  {'feel': 'positive', 'bowl': 'positive', 'past...
# 11                []          {'chicken': 'neutral', 'dish': 'neutral'}
# 12                []  {'refreshing': 'neutral', 'light': 'neutral', ...
# 13          [greasy]       {'anything': 'negative', 'avoid': 'neutral'}
# 14                []  {'spice': 'positive', 'ice': 'neutral', 'somet...
# 15                []  {'workout': 'neutral', 'protein': 'positive', ...
# 16          [sugary]            {'end': 'neutral', 'sugar': 'negative'}
# 17            [meat]  {'today': 'neutral', 'meat': 'negative', 'some...
# 18           [spicy]  {'food': 'negative', 'mood': 'neutral', 'icy':...
# 19                []                                {'dish': 'neutral'}
# 20                []     {'noodle': 'neutral', 'something': 'positive'}
# 21          [garlic]  {'garlic': 'negative', 'anything': 'neutral', ...
# 22         [filling]        {'snack': 'neutral', 'filling': 'negative'}
# 23                []  {'feel': 'neutral', 'food': 'positive', 'comfo...
# 24    [sour, bitter]  {'anything': 'negative', 'avoid': 'neutral', '...
# 25                []  {'crunchy': 'neutral', 'savory': 'neutral', 'c...
# 26                []         {'option': 'neutral', 'prefer': 'neutral'}
# 27       [shellfish]  {'allergic': 'neutral', 'shell': 'negative', '...
# 28                []  {'sweet': 'neutral', 'icy': 'neutral', 'someth...
# 29                []  {'suggest': 'positive', 'pair': 'positive', 's...
# 30        [red meat]  {'today': 'neutral', 'meat': 'negative', 'fish...
# 31           [dairy]  {'cream': 'positive', 'dairy': 'neutral', 'cre...
# 32                []  {'hint': 'neutral', 'lemon': 'neutral', 'meal'...
# 33            [rice]  {'feel': 'positive', 'rice': 'negative', 'anyt...
# 34                []       {'light': 'neutral', 'something': 'neutral'}
# 35  [beans, legumes]  {'bean': 'negative', 'ease': 'positive', 'legu...
# 36                []         {'mushroom': 'neutral', 'dish': 'neutral'}
# 37          [sweets]  {'today': 'neutral', 'sweet': 'negative', 'sna...
# 38         [intense]  {'spice': 'negative', 'intense': 'negative', '...
# 39           [heavy]      {'cheesy': 'neutral', 'something': 'neutral'}
# 40                []           {'bread': 'neutral', 'dish': 'positive'}
# 41                []  {'herb': 'positive', 'meal': 'neutral', 'lot':...
# 42          [onions]  {'today': 'neutral', 'ease': 'negative', 'onio...
# 43                []  {'base': 'neutral', 'meal': 'neutral', 'prefer...
# 44                []  {'season': 'neutral', 'sea': 'neutral', 'end':...
#
#     accuracy_percentage
# 0              0.000000
# 1              0.000000
# 2            100.000000
# 3                   NaN
# 4              0.000000
# 5              0.000000
# 6            100.000000
# 7            100.000000
# 8            100.000000
# 9                   NaN
# 10             0.000000
# 11             0.000000
# 12             0.000000
# 13                  NaN
# 14           100.000000
# 15           100.000000
# 16           100.000000
# 17           100.000000
# 18           100.000000
# 19                  NaN
# 20             0.000000
# 21           100.000000
# 22            50.000000
# 23                  NaN
# 24           100.000000
# 25             0.000000
# 26                  NaN
# 27                  NaN
# 28             0.000000
# 29                  NaN
# 30            66.666667
# 31            50.000000
# 32             0.000000
# 33           100.000000
# 34             0.000000
# 35           100.000000
# 36             0.000000
# 37             0.000000
# 38           100.000000
# 39             0.000000
# 40             0.000000
# 41           100.000000
# 42           100.000000
# 43                  NaN
# 44                  NaN

# %%
average_accuracy = df_trial['accuracy_percentage'].mean(skipna=True)
average_accuracy
# Out:
# 50.476190476190474
